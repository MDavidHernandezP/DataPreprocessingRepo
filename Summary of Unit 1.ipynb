# %% [markdown]
# # Summary of Unit 1
# La tarea consiste en realizar un portafolio de evidencia que compruebe que se ha aprendido a realizar cada uno de los temas listados en el Syllabus, en la Unidad 1.
#
# Para esto se utilizarán las 3 tablas contenidas en el dataset del INEGI.
# Se deberá desarrollar en Python, en una Jupyter Notebook, la cual se deberá subir como entregable para este assignment.

# %% [markdown]
# # Data Import

# %%
# Importando librería pandas abreviada como pd.
import pandas as pd

# %% [markdown]
# ## Dataset Distrito

# %%
# Importando los tres datasets alamacenandolos en diferentes variables (Lo haré en diferentes celdas).
distrito = pd.read_csv("C:/Users/marit/OneDrive/Programming/UPY programming stuff/UPY DATA PREPROCESSING/INEGI Task resources/INE_DISTRITO_2020.CSV", encoding='latin-1')
# Tuve un pequeño problema aquí con el path y su decoding, pero lo arreglé con esto: encoding='latin-1'. 
# Aparentemente por el idioma del dataset o algo dentro de sus bytes no estaba funcionando mi código, pero con esta cosita ya funcionó.

# %%
# Usando un print para desplegar la tabla.
print(distrito)
# Out:
#      ENTIDAD         NOM_ENT   DISTRITO INDIGENA      COMPLEJIDA  POBTOT  \
# 0          1   Aguascalientes         1       NO      Disperso 1  482911
# 1          1   Aguascalientes         2       NO   Concentrado 1  486085
# 2          1   Aguascalientes         3       NO   Concentrado 2  456611
# 3          2  Baja California         1       NO   Concentrado 2  485628
# 4          2  Baja California         2       NO   Concentrado 1  396169
# ..       ...              ...       ...      ...             ...     ...
# 295       31          Yucatán         5       SI      Disperso 1  440998
# 296       32        Zacatecas         1       NO      Disperso 1  401248
# 297       32        Zacatecas         2       NO  Muy Disperso 1  382209
# 298       32        Zacatecas         3       NO      Disperso 2  388643
# 299       32        Zacatecas         4       NO      Disperso 1  450038
#
#      POBFEM  POBMAS  P_0A2  P_0A2_F  ...  VPH_TELEF  VPH_CEL  VPH_INTER  \
# ...

# %%
# Usando la función (columns) para ver todas mis columnas.
distrito.columns
# Out:
# Index(['ENTIDAD', 'NOM_ENT ', 'DISTRITO', 'INDIGENA', 'COMPLEJIDA', 'POBTOT',
#        'POBFEM', 'POBMAS', 'P_0A2', 'P_0A2_F',
#        ...
#        'VPH_TELEF', 'VPH_CEL', 'VPH_INTER', 'VPH_STVP', 'VPH_SPMVPI',
#        'VPH_CVJ', 'VPH_SINRTV', 'VPH_SINLTC', 'VPH_SINCIN', 'VPH_SINTIC'],
#       dtype='object', length=225)

# %%
# Usando función (info) para ver más específicaciones de mi dataset.
distrito.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Columns: 225 entries, ENTIDAD to VPH_SINTIC
# dtypes: int64(222), object(3)
# memory usage: 527.5+ KB

# %%
# Ahora usaré la función (dtypes) para ver el tipo de datos de cada columna
distrito.dtypes
# Out:
# ENTIDAD        int64
# NOM_ENT       object
# DISTRITO       int64
# INDIGENA      object
# COMPLEJIDA    object
#                ...
# VPH_CVJ        int64
# VPH_SINRTV     int64
# VPH_SINLTC     int64
# VPH_SINCIN     int64
# VPH_SINTIC     int64
# Length: 225, dtype: object

# %% [markdown]
# ## Dataset Entidad

# %%
# Importando los tres datasets alamacenandolos en diferentes variables (Lo haré en diferentes celdas).
entidad = pd.read_csv("C:/Users/marit/OneDrive/Programming/UPY programming stuff/UPY DATA PREPROCESSING/INEGI Task resources/INE_ENTIDAD_2020.CSV", encoding='latin-1')
# Tuve un pequeño problema aquí con el path y su decoding, pero lo arreglé con esto: encoding='latin-1'. 
# Aparentemente por el idioma del dataset o algo dentro de sus bytes no estaba funcionando mi código, pero con esta cosita ya funcionó.

# %%
# Usando un print para desplegar la tabla.
print(entidad)
# Out:
#     ENT                         NOM_ENT     POBTOT   POBFEM   POBMAS   P_0A2  \
# 0     1                   Aguascalientes   1425607   728924   696683   71864
# 1     2                  Baja California   3769020  1868431  1900589  149957
# 2     3              Baja California Sur    798447   392568   405879   35963
# 3     4                         Campeche    928363   471424   456939   45541
# 4     5             Coahuila de Zaragoza   3146771  1583102  1563669  160368
# 5     6                           Colima    731391   370769   360622   29614
# 6     7                          Chiapas   5543828  2837881  2705947  334055
# 7     8                        Chihuahua   3741869  1888047  1853822  163950
# 8     9                 Ciudad de México   9209944  4805017  4404927  267151
# 9    10                          Durango   1832650   927784   904866   95793
# 10   11                       Guanajuato   6166934  3170480  2996454  313928
# ...

# %%
# Usando la función (columns) para ver todas mis columnas.
entidad.columns
# Out:
# Index(['ENT', 'NOM_ENT ', 'POBTOT', 'POBFEM', 'POBMAS', 'P_0A2', 'P_0A2_F',
#        'P_0A2_M', 'P_0A17', 'P_3YMAS',
#        ...
#        'VPH_TELEF', 'VPH_CEL', 'VPH_INTER', 'VPH_STVP', 'VPH_SPMVPI',
#        'VPH_CVJ', 'VPH_SINRTV', 'VPH_SINLTC', 'VPH_SINCIN', 'VPH_SINTIC'],
#       dtype='object', length=222)

# %%
# Usando función (info) para ver más específicaciones de mi dataset.
entidad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Columns: 222 entries, ENT to VPH_SINTIC
# dtypes: float64(7), int64(214), object(1)
# memory usage: 55.6+ KB

# %%
# Ahora usaré la función (dtypes) para ver el tipo de datos de cada columna
entidad.dtypes
# Out:
# ENT            int64
# NOM_ENT       object
# POBTOT         int64
# POBFEM         int64
# POBMAS         int64
#                ...
# VPH_CVJ        int64
# VPH_SINRTV     int64
# VPH_SINLTC     int64
# VPH_SINCIN     int64
# VPH_SINTIC     int64
# Length: 222, dtype: object

# %% [markdown]
# ## Dataset Sección

# %%
# Importando los tres datasets alamacenandolos en diferentes variables (Lo haré en diferentes celdas).
seccion = pd.read_csv("C:/Users/marit/OneDrive/Programming/UPY programming stuff/UPY DATA PREPROCESSING/INEGI Task resources/INE_SECCION_2020.csv")

# %%
# Usando un print para desplegar la tabla.
print(seccion)
# Out:
#          ID  ENTIDAD  DISTRITO  MUNICIPIO  SECCION  TIPO  POBTOT  POBFEM  \
# 0       118        1         3          1        1     2    2564    1360
# 1       122        1         3          1        2     2     889     462
# 2       128        1         3          1        3     2    2003    1057
# 3       137        1         3          1        4     2    1636     880
# 4       138        1         3          1        5     2     808     445
# ...     ...      ...       ...        ...      ...   ...     ...     ...
# 68801   910       32         4         17     1907     2    1027     527
# 68802   912       32         4         17     1908     2    1589     832
# 68803   913       32         4         17     1909     2     269     133
# 68804  1956       32         3         39     1910     3    2915    1487
# 68805  1955       32         3         39     1911     3    3868    1982
#
#        POBMAS  P_0A2  ...  VPH_TELEF  VPH_CEL  VPH_INTER  VPH_STVP  \
# ...

# %%
# Usando la función (columns) para ver todas mis columnas.
seccion.columns
# Out:
# Index(['ID', 'ENTIDAD', 'DISTRITO', 'MUNICIPIO', 'SECCION', 'TIPO', 'POBTOT',
#        'POBFEM', 'POBMAS', 'P_0A2',
#        ...
#        'VPH_TELEF', 'VPH_CEL', 'VPH_INTER', 'VPH_STVP', 'VPH_SPMVPI',
#        'VPH_CVJ', 'VPH_SINRTV', 'VPH_SINLTC', 'VPH_SINCIN', 'VPH_SINTIC'],
#       dtype='object', length=226)

# %%
# Usando función (info) para ver más específicaciones de mi dataset.
seccion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68806 entries, 0 to 68805
# Columns: 226 entries, ID to VPH_SINTIC
# dtypes: float64(7), int64(219)
# memory usage: 118.6 MB

# %%
# Ahora usaré la función (dtypes) para ver el tipo de datos de cada columna
seccion.dtypes
# Out:
# ID            int64
# ENTIDAD       int64
# DISTRITO      int64
# MUNICIPIO     int64
# SECCION       int64
#               ...
# VPH_CVJ       int64
# VPH_SINRTV    int64
# VPH_SINLTC    int64
# VPH_SINCIN    int64
# VPH_SINTIC    int64
# Length: 226, dtype: object

# %% [markdown]
# # Data Exploration

# %% [markdown]
# ## Dataset Distrito

# %%
# Haciendo una mejor visualización de las primeras 5 filas de (distrito), para un mejor entendimiento.
distrito.head(5)
# Out:
#    ENTIDAD         NOM_ENT   DISTRITO INDIGENA     COMPLEJIDA  POBTOT  POBFEM  \
# 0        1   Aguascalientes         1       NO     Disperso 1  482911  245249
# 1        1   Aguascalientes         2       NO  Concentrado 1  486085  249098
# 2        1   Aguascalientes         3       NO  Concentrado 2  456611  234577
# 3        2  Baja California         1       NO  Concentrado 2  485628  240417
# 4        2  Baja California         2       NO  Concentrado 1  396169  197545
#
#    POBMAS  P_0A2  P_0A2_F  ...  VPH_TELEF  VPH_CEL  VPH_INTER  VPH_STVP  \
# 0  237662  27689    13802  ...      32683   110208      59381     45106
# 1  236987  24904    12319  ...      51688   126004      84830     63907
# 2  222034  19271     9483  ...      63447   123683      91792     65076
# 3  245211  19179     9563  ...      70615   141300      97720     72397
# 4  198624  11110     5479  ...      82630   119147      97297     65908
#
# ...

# %%
# Haciendo una mejor visualización de las primeras 5 filas de (distrito), para un mejor entendimiento.
distrito.tail(5)
# Out:
#      ENTIDAD   NOM_ENT   DISTRITO INDIGENA      COMPLEJIDA  POBTOT  POBFEM  \
# 295       31    Yucatán         5       SI      Disperso 1  440998  221243
# 296       32  Zacatecas         1       NO      Disperso 1  401248  204384
# 297       32  Zacatecas         2       NO  Muy Disperso 1  382209  195915
# 298       32  Zacatecas         3       NO      Disperso 2  388643  198960
# 299       32  Zacatecas         4       NO      Disperso 1  450038  231821
#
#      POBMAS  P_0A2  P_0A2_F  ...  VPH_TELEF  VPH_CEL  VPH_INTER  VPH_STVP  \
# 295  219755  22989    11341  ...       9970    92325      36036     64935
# 296  196864  23355    11498  ...      29959    89927      48632     51412
# 297  186294  20205    10044  ...      34309    88813      44615     48299
# 298  189683  19795     9818  ...      38288    89258      53611     57594
# 299  218217  25078    12460  ...      35496   104816      58087     57032
#
# ...

# %%
# Ahora usaré la función (describe) par ver un resumen estadístico de las columnas numéricas.
distrito.describe()
# Out:
#           ENTIDAD    DISTRITO         POBTOT         POBFEM         POBMAS  \
# count  300.000000  300.000000     300.000000     300.000000     300.000000
# mean    16.476667    8.523333  420046.746667  215135.446667  204911.300000
# std      7.939747    8.140250   59313.093187   29164.659537   30615.940435
# min      1.000000    1.000000  318965.000000  158800.000000  155137.000000
# 25%     11.000000    3.000000  387111.500000  198327.750000  186982.750000
# 50%     15.000000    6.000000  413567.500000  212140.000000  200654.000000
# 75%     22.000000   11.000000  444328.000000  227850.000000  215679.500000
# max     32.000000   41.000000  840624.000000  415157.000000  425467.000000
#
#               P_0A2       P_0A2_F       P_0A2_M         P_0A17        P_3YMAS  \
# count    300.000000    300.000000    300.000000     300.000000     300.000000
# mean   19213.513333   9496.250000   9717.263333  127493.193333  399921.946667
# ...

# %% [markdown]
# ## Dataset Entidad

# %%
# Haciendo una mejor visualización de las primeras 5 filas de (entidad), para un mejor entendimiento.
entidad.head(5)
# Out:
#    ENT              NOM_ENT    POBTOT   POBFEM   POBMAS   P_0A2  P_0A2_F  \
# 0    1        Aguascalientes  1425607   728924   696683   71864    35604
# 1    2       Baja California  3769020  1868431  1900589  149957    74010
# 2    3   Baja California Sur   798447   392568   405879   35963    17821
# 3    4              Campeche   928363   471424   456939   45541    22506
# 4    5  Coahuila de Zaragoza  3146771  1583102  1563669  160368    79095
#
#    P_0A2_M   P_0A17  P_3YMAS  ...  VPH_TELEF  VPH_CEL  VPH_INTER  VPH_STVP  \
# 0    36260   463335  1352235  ...     147818   359895     236003    174089
# 1    75947  1061893  3610844  ...     576806  1080169     800189    618175
# 2    18142   236629   758642  ...      91750   226517     148723    136538
# 3    23035   286880   878528  ...      68843   218322     114020    151613
# 4    81273   982841  2980244  ...     372132   824291     519599    443659
#
#    VPH_SPMVPI  VPH_CVJ  VPH_SINRTV  VPH_SINLTC  VPH_SINCIN  VPH_SINTIC
# ...

# %%
# Haciendo una mejor visualización de las últimas 5 filas de (entidad), para un mejor entendimiento.
entidad.tail(5)
# Out:
#     ENT                         NOM_ENT    POBTOT   POBFEM   POBMAS   P_0A2  \
# 27   28                       Tamaulipas  3527735  1791595  1736140  154958
# 28   29                         Tlaxcala  1342977   693083   649894   63959
# 29   30  Veracruz de Ignacio de la Llave  8062579  4190805  3871774  342746
# 30   31                          Yucatán  2320898  1180619  1140279  101151
# 31   32                        Zacatecas  1622138   831080   791058   88433
#
#     P_0A2_F  P_0A2_M   P_0A17  P_3YMAS  ...  VPH_TELEF  VPH_CEL  VPH_INTER  \
# 27    76445    78513  1046920  3367123  ...     413157   985027     580241
# 28    31786    32173   421140  1258093  ...      97434   289686     131845
# 29   169702   173044  2378935  7716363  ...     635994  1971776     959542
# 30    49841    51310   666922  2215931  ...     176401   580440     339142
# 31    43820    44613   544684  1531847  ...     138052   372814     204945
#
# ...

# %%
# Ahora usaré la función (describe) par ver un resumen estadístico de las columnas numéricas.
entidad.describe()
# Out:
#              ENT        POBTOT        POBFEM        POBMAS          P_0A2  \
# count  32.000000  3.200000e+01  3.200000e+01  3.200000e+01      32.000000
# mean   16.500000  3.937938e+06  2.016895e+06  1.921043e+06  180126.687500
# std     9.380832  3.278009e+06  1.692778e+06  1.585771e+06  140571.778417
# min     1.000000  7.313910e+05  3.707690e+05  3.606220e+05   29614.000000
# 25%     8.750000  1.851651e+06  9.261395e+05  9.288008e+05   87423.000000
# 50%    16.500000  3.054892e+06  1.557615e+06  1.488097e+06  137070.500000
# 75%    24.250000  4.947592e+06  2.541349e+06  2.406242e+06  253391.500000
# max    32.000000  1.699242e+07  8.741123e+06  8.251295e+06  724133.000000
#
#              P_0A2_F        P_0A2_M        P_0A17       P_3YMAS     P_3YMAS_F  \
# count      32.000000      32.000000  3.200000e+01  3.200000e+01  3.200000e+01
# mean    89027.343750   91099.343750  1.195249e+06  3.749268e+06  1.923580e+06
# ...

# %% [markdown]
# ## Dataset Sección

# %%
# Haciendo una mejor visualización de las últimas 5 filas de (seccion), para un mejor entendimiento.
seccion.head(5)
# Out:
#     ID  ENTIDAD  DISTRITO  MUNICIPIO  SECCION  TIPO  POBTOT  POBFEM  POBMAS  \
# 0  118        1         3          1        1     2    2564    1360    1204
# 1  122        1         3          1        2     2     889     462     427
# 2  128        1         3          1        3     2    2003    1057     946
# 3  137        1         3          1        4     2    1636     880     756
# 4  138        1         3          1        5     2     808     445     363
#
#    P_0A2  ...  VPH_TELEF  VPH_CEL  VPH_INTER  VPH_STVP  VPH_SPMVPI  VPH_CVJ  \
# 0     36  ...        698      740        738       659         615      288
# 1     27  ...        173      253        195       164         145       54
# 2     56  ...        426      621        559       360         335      184
# 3     40  ...        311      507        456       330         329      147
# 4     14  ...        188      256        233       168         119       70
#
#    VPH_SINRTV  VPH_SINLTC  VPH_SINCIN  VPH_SINTIC
# ...

# %%
# Haciendo una mejor visualización de las últimas 5 filas de (seccion), para un mejor entendimiento.
seccion.tail(5)
# Out:
#          ID  ENTIDAD  DISTRITO  MUNICIPIO  SECCION  TIPO  POBTOT  POBFEM  \
# 68801   910       32         4         17     1907     2    1027     527
# 68802   912       32         4         17     1908     2    1589     832
# 68803   913       32         4         17     1909     2     269     133
# 68804  1956       32         3         39     1910     3    2915    1487
# 68805  1955       32         3         39     1911     3    3868    1982
#
#        POBMAS  P_0A2  ...  VPH_TELEF  VPH_CEL  VPH_INTER  VPH_STVP  \
# 68801     500     24  ...        170      290        272       237
# 68802     757     54  ...        249      461        411       365
# 68803     136     13  ...         30       73         60        53
# 68804    1428    162  ...        266      715        411       448
# 68805    1886    217  ...        288     1027        728       561
#
#        VPH_SPMVPI  VPH_CVJ  VPH_SINRTV  VPH_SINLTC  VPH_SINCIN  VPH_SINTIC
# ...

# %%
# Ahora usaré la función (describe) par ver un resumen estadístico de las columnas numéricas.
seccion.describe()
# Out:
#                  ID       ENTIDAD      DISTRITO     MUNICIPIO       SECCION  \
# count  68806.000000  68806.000000  68806.000000  68806.000000  68806.000000
# mean    2257.964044     16.860753      7.599672     48.347223   1604.947417
# std     2900.314005      8.286648      7.310902     66.196288   1356.936637
# min        1.000000      1.000000      1.000000      1.000000      1.000000
# 25%      608.000000     10.000000      3.000000     10.000000    558.000000
# 50%     1349.000000     15.000000      5.000000     30.000000   1255.000000
# 75%     2485.000000     24.000000     10.000000     59.000000   2275.000000
# max    50511.000000     32.000000     41.000000    570.000000   6637.000000
#
#                TIPO        POBTOT        POBFEM        POBMAS         P_0A2  \
# count  68806.000000  68806.000000  68806.000000  68806.000000  68806.000000
# mean       2.633608   1831.439467    938.008255    893.430050     83.772026
# ...

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Dataset Distrito

# %%
# Ahora averiguaré si el dataset tiene filas duplicadas.
distrito.drop_duplicates(inplace=True)
distrito.shape
# Out:
# (300, 225)

# %% [markdown]
# Como podemos apreciar el dataset aparenta no tener filas duplicadas, ya que contiene la misma forma que en nuestra primera instancia de la función (shape).

# %%
# Vamos a crear una copia de nuestro dataset para ver si tiene valores nulos.
distrito_cp = distrito.copy()

# %%
# Usaremos (dropna) para remover las filas con valores nulos.
distrito_cp.dropna(axis = 0 , inplace=True ) 
# Ahora checaremos con (info).
distrito_cp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Columns: 225 entries, ENTIDAD to VPH_SINTIC
# dtypes: int64(222), object(3)
# memory usage: 527.5+ KB

# %% [markdown]
# Ahora si comprobamos con la cantidad de valores de nuestro primer instancia de la función (info) podemos percatarnos de que los valores son los mimos por ende no hay valores duplicados.

# %% [markdown]
# ## Dataset Entidad

# %%
# Ahora averiguaré si el dataset tiene filas duplicadas.
entidad.drop_duplicates(inplace=True)
entidad.shape
# Out:
# (32, 222)

# %% [markdown]
# Como podemos apreciar el dataset aparenta no tener filas duplicadas, ya que contiene la misma forma que en nuestra primera instancia de la función (shape).

# %%
# Vamos a crear una copia de nuestro dataset para ver si tiene valores nulos.
entidad_cp = entidad.copy()

# %%
# Usaremos (dropna) para remover las filas con valores nulos.
entidad_cp.dropna(axis = 0 , inplace=True ) 
# Ahora checaremos con (info).
entidad_cp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Columns: 222 entries, ENT to VPH_SINTIC
# dtypes: float64(7), int64(214), object(1)
# memory usage: 55.6+ KB

# %% [markdown]
# Ahora si comprobamos con la cantidad de valores de nuestro primer instancia de la función (info) podemos percatarnos de que los valores son los mimos por ende no hay valores duplicados.

# %% [markdown]
# ## Dataset Sección

# %%
# Ahora averiguaré si el dataset tiene filas duplicadas.
seccion.drop_duplicates(inplace=True)
seccion.shape
# Out:
# (68806, 226)

# %% [markdown]
# Como podemos apreciar el dataset aparenta no tener filas duplicadas, ya que contiene la misma forma que en nuestra primera instancia de la función (shape).

# %%
# Vamos a crear una copia de nuestro dataset para ver si tiene valores nulos.
seccion_cp = seccion.copy()

# %%
# Usaremos (dropna) para remover las filas con valores nulos.
seccion_cp.dropna(axis = 0 , inplace=True ) 
# Ahora checaremos con (info).
seccion_cp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68806 entries, 0 to 68805
# Columns: 226 entries, ID to VPH_SINTIC
# dtypes: float64(7), int64(219)
# memory usage: 118.6 MB

# %% [markdown]
# Ahora si comprobamos con la cantidad de valores de nuestro primer instancia de la función (info) podemos percatarnos de que los valores son los mimos por ende no hay valores duplicados.

# %% [markdown]
# # Data Transformation

# %% [markdown]
# ## Dataset Distrito

# %% [markdown]
# Ahora que ya revisamos y limpiamos lo que pudimos del dataset nos queda nada más transformar lo que podamos siempre con el fin de optimizar y tener una mejor comprensión de lo que estamos viendo.

# %%
# Entonces una cosa que podemos hacer ahora es buscar las columnas con valores categóricos.
# Con estas columnas crear más columnas para poder ver mejor las ocurrencias o frecuencia de estos valores.
# Entonces ahora usaré esta técnica para la columna (COMPLEJIDA).
pd.get_dummies(distrito.COMPLEJIDA)
# Out:
#      Altamente Concentrado 1  Altamente Concentrado 2  Concentración Media  \
# 0                      False                    False                False
# 1                      False                    False                False
# 2                      False                    False                False
# 3                      False                    False                False
# 4                      False                    False                False
# ..                       ...                      ...                  ...
# 295                    False                    False                False
# 296                    False                    False                False
# 297                    False                    False                False
# 298                    False                    False                False
# 299                    False                    False                False
#
# ...

# %%
# También podemos hacer esto con la columna (NOM_ENT).
# Pero primero cambiaremos el nombre de esta columna ya que tiene un error con un espacio.
distrito.rename(columns = {'NOM_ENT ':'NOM_ENT'}, inplace = True)
# Y ahora si ya deberíamos poder realizar esta conversión.
pd.get_dummies(distrito.NOM_ENT)
# Out:
#      Aguascalientes  Baja California  Baja California Sur  Campeche  Chiapas  \
# 0              True            False                False     False    False
# 1              True            False                False     False    False
# 2              True            False                False     False    False
# 3             False             True                False     False    False
# 4             False             True                False     False    False
# ..              ...              ...                  ...       ...      ...
# 295           False            False                False     False    False
# 296           False            False                False     False    False
# 297           False            False                False     False    False
# 298           False            False                False     False    False
# 299           False            False                False     False    False
#
# ...

# %%
# Esto tabién se lo podemos aplicar a la columna (INDIGENA)
pd.get_dummies(distrito.INDIGENA)
# Out:
#         NO     SI
# 0     True  False
# 1     True  False
# 2     True  False
# 3     True  False
# 4     True  False
# ..     ...    ...
# 295  False   True
# 296   True  False
# 297   True  False
# 298   True  False
# 299   True  False
#
# [300 rows x 2 columns]

# %% [markdown]
# ## Dataset Entidad

# %% [markdown]
# Ahora que ya revisamos y limpiamos lo que pudimos del dataset nos queda nada más transformar lo que podamos siempre con el fin de optimizar y tener una mejor comprensión de lo que estamos viendo.

# %%
# Entonces una cosa que podemos hacer ahora es buscar las columnas con valores categóricos.
# Con estas columnas crear más columnas para poder ver mejor las ocurrencias o frecuencia de estos valores.
# Entonces ahora usaré esta técnica para la columna (NOM_ENT).
# Pero primero cambiaremos el nombre de esta columna ya que tiene un error con un espacio.
entidad.rename(columns = {'NOM_ENT ':'NOM_ENT'}, inplace = True)
# Ahora si, ya con el problema resuelto hacemosn la conversión
pd.get_dummies(entidad.NOM_ENT)
# Out:
#     Aguascalientes  Baja California  Baja California Sur  Campeche  Chiapas  \
# 0             True            False                False     False    False
# 1            False             True                False     False    False
# 2            False            False                 True     False    False
# 3            False            False                False      True    False
# 4            False            False                False     False    False
# 5            False            False                False     False    False
# 6            False            False                False     False     True
# 7            False            False                False     False    False
# 8            False            False                False     False    False
# 9            False            False                False     False    False
# 10           False            False                False     False    False
# ...

# %% [markdown]
# ## Dataset Sección

# %% [markdown]
# Ahora que ya revisamos y limpiamos lo que pudimos del dataset nos queda nada más transformar lo que podamos siempre con el fin de optimizar y tener una mejor comprensión de lo que estamos viendo.

# %%
# Aquí aplicaría de nuevo lo que hicimos antes ocn los otros 2 datasets. 
# El problema es que este dataset no cuenta con columnas categóricas, entonces no funcionaría.
# Aseguremos que esto es cierto.
seccion
# Out:
#          ID  ENTIDAD  DISTRITO  MUNICIPIO  SECCION  TIPO  POBTOT  POBFEM  \
# 0       118        1         3          1        1     2    2564    1360
# 1       122        1         3          1        2     2     889     462
# 2       128        1         3          1        3     2    2003    1057
# 3       137        1         3          1        4     2    1636     880
# 4       138        1         3          1        5     2     808     445
# ...     ...      ...       ...        ...      ...   ...     ...     ...
# 68801   910       32         4         17     1907     2    1027     527
# 68802   912       32         4         17     1908     2    1589     832
# 68803   913       32         4         17     1909     2     269     133
# 68804  1956       32         3         39     1910     3    2915    1487
# 68805  1955       32         3         39     1911     3    3868    1982
#
#        POBMAS  P_0A2  ...  VPH_TELEF  VPH_CEL  VPH_INTER  VPH_STVP  \
# ...

# %% [markdown]
# Como podemos apreciar en efecto solo cuenta con valores númericos en todas sus columnas entonces en este caso nos convendría hacer un (describe) pero eso ya lo aplicamos antes en el notebook así que y con esto sería todo.
