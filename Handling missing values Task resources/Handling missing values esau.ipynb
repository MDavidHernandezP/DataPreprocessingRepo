# %%
#Importar Librerías
import pandas as pd
#Load Data usando la función read_csv
data = pd.read_csv("C:/Users/Personal/OneDrive/Programming/UPY programming stuff/UPY DATA PREPROCESSING/Handling missing values resources/ModalidadVirtual.csv")
print(data)
#Corregir problema de indexado con el que viene el dataset ya que sin esto no podemos realizar unos pasos más adelante
data.set_index(data.columns[0], inplace=True)
# Out:
#      Unnamed: 0        time                       carrera acepta  \
# 0             0  2020-11-08        Ingeniería de Sistemas     Si
# 1             1  2020-11-08                    Psicología     Si
# 2             2  2020-11-08        Ingeniería de Sistemas     Si
# 3             3  2020-11-08        Ingeniería de Sistemas     Si
# 4             4  2020-11-08        Ingeniería de Sistemas     Si
# ..          ...         ...                           ...    ...
# 217         230  2020-12-10  Gestión Turística y Hotelera     Si
# 218         231  2020-12-11        Ingeniería de Sistemas     No
# 219         232  2020-12-11  Gestión Turística y Hotelera     No
# 220         233  2020-12-11         Ingeniería Agronómica     Si
# 221         234  2020-12-12        Comercio Internacional     Si
#
#                           positivo  \
# 0                Horario flexible.
# 1    Acceso desde cualquier lugar.
# 2                Horario flexible.
# 3                Horario flexible.
# 4    Acceso desde cualquier lugar.
# ..                             ...
# 217              Horario flexible.
# 218  Acceso desde cualquier lugar.
# 219              Horario flexible.
# 220  Acceso desde cualquier lugar.
# 221              Horario flexible.
#
#                                               negativo  edad    sexo   trabajo
# 0               Contacto Personal Docente-Estudiantil.    20  Hombre  Eventual
# 1               Contacto Personal Docente-Estudiantil.    26  Hombre  Eventual
# 2    Falta de recursos de calidad(plataformas, doce...    20   Mujer        Sí
# 3                                 Conexión a internet.    18   Mujer        No
# 4               Contacto Personal Docente-Estudiantil.    39  Hombre        Sí
# ..                                                 ...   ...     ...       ...
# 217                               Conexión a internet.    19   Mujer        Sí
# 218  Falta de recursos de calidad(plataformas, doce...    23   Mujer        No
# 219  Falta de recursos de calidad(plataformas, doce...    25  Hombre        Sí
# 220             Contacto Personal Docente-Estudiantil.    20   Mujer        Sí
# 221  Falta de recursos de calidad(plataformas, doce...    23  Hombre        Sí
#
# [222 rows x 9 columns]

# %%
#Delete features with more than 70% missing values
print("Delete features with more than 70% missing values")
#A partir de aquí empecé a poner prints de lo que hacen para que se diferencien en la terminal
umbral1 = 0.7 * len(data.columns)
data_missing_70 = data.dropna(thresh=umbral1)
#Aquí use el parámetro thresh para poder especificar un umbral de valores no nulos
#Y con el dropna para eliminar las filas
print(data_missing_70)
# Out:
# Delete features with more than 70% missing values
#                   time                       carrera acepta  \
# Unnamed: 0
# 0           2020-11-08        Ingeniería de Sistemas     Si
# 1           2020-11-08                    Psicología     Si
# 2           2020-11-08        Ingeniería de Sistemas     Si
# 3           2020-11-08        Ingeniería de Sistemas     Si
# 4           2020-11-08        Ingeniería de Sistemas     Si
# ...                ...                           ...    ...
# 230         2020-12-10  Gestión Turística y Hotelera     Si
# 231         2020-12-11        Ingeniería de Sistemas     No
# 232         2020-12-11  Gestión Turística y Hotelera     No
# 233         2020-12-11         Ingeniería Agronómica     Si
# 234         2020-12-12        Comercio Internacional     Si
#
#                                  positivo  \
# Unnamed: 0
# 0                       Horario flexible.
# 1           Acceso desde cualquier lugar.
# 2                       Horario flexible.
# 3                       Horario flexible.
# 4           Acceso desde cualquier lugar.
# ...                                   ...
# 230                     Horario flexible.
# 231         Acceso desde cualquier lugar.
# 232                     Horario flexible.
# 233         Acceso desde cualquier lugar.
# 234                     Horario flexible.
#
#                                                      negativo  edad    sexo  \
# Unnamed: 0
# 0                      Contacto Personal Docente-Estudiantil.    20  Hombre
# 1                      Contacto Personal Docente-Estudiantil.    26  Hombre
# 2           Falta de recursos de calidad(plataformas, doce...    20   Mujer
# 3                                        Conexión a internet.    18   Mujer
# 4                      Contacto Personal Docente-Estudiantil.    39  Hombre
# ...                                                       ...   ...     ...
# 230                                      Conexión a internet.    19   Mujer
# 231         Falta de recursos de calidad(plataformas, doce...    23   Mujer
# 232         Falta de recursos de calidad(plataformas, doce...    25  Hombre
# 233                    Contacto Personal Docente-Estudiantil.    20   Mujer
# 234         Falta de recursos de calidad(plataformas, doce...    23  Hombre
#
#              trabajo
# Unnamed: 0
# 0           Eventual
# 1           Eventual
# 2                 Sí
# 3                 No
# 4                 Sí
# ...              ...
# 230               Sí
# 231               No
# 232               Sí
# 233               Sí
# 234               Sí
#
# [222 rows x 8 columns]

# %%
#Delete observations with more than 50% missing values
print("Delete observations with more than 50% missing values")
umbral2 = 0.5 * len(data.columns)
data_missing_50 = data.dropna(thresh=umbral2)
#Básicamente apliqué lo mismo pero con diferentes valores
print(data_missing_50)
# Out:
# Delete observations with more than 50% missing values
#                   time                       carrera acepta  \
# Unnamed: 0
# 0           2020-11-08        Ingeniería de Sistemas     Si
# 1           2020-11-08                    Psicología     Si
# 2           2020-11-08        Ingeniería de Sistemas     Si
# 3           2020-11-08        Ingeniería de Sistemas     Si
# 4           2020-11-08        Ingeniería de Sistemas     Si
# ...                ...                           ...    ...
# 230         2020-12-10  Gestión Turística y Hotelera     Si
# 231         2020-12-11        Ingeniería de Sistemas     No
# 232         2020-12-11  Gestión Turística y Hotelera     No
# 233         2020-12-11         Ingeniería Agronómica     Si
# 234         2020-12-12        Comercio Internacional     Si
#
#                                  positivo  \
# Unnamed: 0
# 0                       Horario flexible.
# 1           Acceso desde cualquier lugar.
# 2                       Horario flexible.
# 3                       Horario flexible.
# 4           Acceso desde cualquier lugar.
# ...                                   ...
# 230                     Horario flexible.
# 231         Acceso desde cualquier lugar.
# 232                     Horario flexible.
# 233         Acceso desde cualquier lugar.
# 234                     Horario flexible.
#
#                                                      negativo  edad    sexo  \
# Unnamed: 0
# 0                      Contacto Personal Docente-Estudiantil.    20  Hombre
# 1                      Contacto Personal Docente-Estudiantil.    26  Hombre
# 2           Falta de recursos de calidad(plataformas, doce...    20   Mujer
# 3                                        Conexión a internet.    18   Mujer
# 4                      Contacto Personal Docente-Estudiantil.    39  Hombre
# ...                                                       ...   ...     ...
# 230                                      Conexión a internet.    19   Mujer
# 231         Falta de recursos de calidad(plataformas, doce...    23   Mujer
# 232         Falta de recursos de calidad(plataformas, doce...    25  Hombre
# 233                    Contacto Personal Docente-Estudiantil.    20   Mujer
# 234         Falta de recursos de calidad(plataformas, doce...    23  Hombre
#
#              trabajo
# Unnamed: 0
# 0           Eventual
# 1           Eventual
# 2                 Sí
# 3                 No
# 4                 Sí
# ...              ...
# 230               Sí
# 231               No
# 232               Sí
# 233               Sí
# 234               Sí
#
# [222 rows x 8 columns]

# %%
#Check for duplicated rows
print("Check for duplicated rows")
data_unduplicate = data.drop_duplicates()
print(data_unduplicate)

data_duplicated_rows = data[data.duplicated()]
print(data_duplicated_rows)
# Out:
# Check for duplicated rows
#                   time                       carrera acepta  \
# Unnamed: 0
# 0           2020-11-08        Ingeniería de Sistemas     Si
# 1           2020-11-08                    Psicología     Si
# 2           2020-11-08        Ingeniería de Sistemas     Si
# 3           2020-11-08        Ingeniería de Sistemas     Si
# 4           2020-11-08        Ingeniería de Sistemas     Si
# ...                ...                           ...    ...
# 230         2020-12-10  Gestión Turística y Hotelera     Si
# 231         2020-12-11        Ingeniería de Sistemas     No
# 232         2020-12-11  Gestión Turística y Hotelera     No
# 233         2020-12-11         Ingeniería Agronómica     Si
# 234         2020-12-12        Comercio Internacional     Si
#
#                                  positivo  \
# Unnamed: 0
# 0                       Horario flexible.
# 1           Acceso desde cualquier lugar.
# 2                       Horario flexible.
# 3                       Horario flexible.
# 4           Acceso desde cualquier lugar.
# ...                                   ...
# 230                     Horario flexible.
# 231         Acceso desde cualquier lugar.
# 232                     Horario flexible.
# 233         Acceso desde cualquier lugar.
# 234                     Horario flexible.
#
#                                                      negativo  edad    sexo  \
# Unnamed: 0
# 0                      Contacto Personal Docente-Estudiantil.    20  Hombre
# 1                      Contacto Personal Docente-Estudiantil.    26  Hombre
# 2           Falta de recursos de calidad(plataformas, doce...    20   Mujer
# 3                                        Conexión a internet.    18   Mujer
# 4                      Contacto Personal Docente-Estudiantil.    39  Hombre
# ...                                                       ...   ...     ...
# 230                                      Conexión a internet.    19   Mujer
# 231         Falta de recursos de calidad(plataformas, doce...    23   Mujer
# 232         Falta de recursos de calidad(plataformas, doce...    25  Hombre
# 233                    Contacto Personal Docente-Estudiantil.    20   Mujer
# 234         Falta de recursos de calidad(plataformas, doce...    23  Hombre
#
#              trabajo
# Unnamed: 0
# 0           Eventual
# 1           Eventual
# 2                 Sí
# 3                 No
# 4                 Sí
# ...              ...
# 230               Sí
# 231               No
# 232               Sí
# 233               Sí
# 234               Sí
#
# [213 rows x 8 columns]
#                   time                 carrera acepta  \
# Unnamed: 0
# 8           2020-11-08  Ingeniería de Sistemas     Si
# 26          2020-11-09                 Derecho     Si
# 61          2020-11-09  Ingeniería de Sistemas     Si
# 63          2020-11-09  Ingeniería de Sistemas     Si
# 88          2020-11-10                 Derecho     Si
# 89          2020-11-10                 Derecho     Si
# 167         2020-11-24              Psicología     Si
# 174         2020-11-26                 Derecho     Si
# 176         2020-11-26      Ciencias Políticas     Si
#
#                                  positivo  \
# Unnamed: 0
# 8                       Horario flexible.
# 26          Acceso desde cualquier lugar.
# 61                      Horario flexible.
# 63                      Horario flexible.
# 88                      Horario flexible.
# 89                      Horario flexible.
# 167                     Horario flexible.
# 174         Acceso desde cualquier lugar.
# 176         Acceso desde cualquier lugar.
#
#                                           negativo  edad    sexo   trabajo
# Unnamed: 0
# 8           Contacto Personal Docente-Estudiantil.    20  Hombre        Sí
# 26          Contacto Personal Docente-Estudiantil.    34   Mujer        Sí
# 61          Contacto Personal Docente-Estudiantil.    33  Hombre        Sí
# 63          Contacto Personal Docente-Estudiantil.    45  Hombre        Sí
# 88                            Conexión a internet.    38   Mujer  Eventual
# 89                            Conexión a internet.    38   Mujer  Eventual
# 167                           Conexión a internet.    32   Mujer        Sí
# 174                           Conexión a internet.    36   Mujer  Eventual
# 176                           Conexión a internet.    43  Hombre        Sí

# %%
#Delete features with average equal to Zero
print("Delete features with average equal to Zero")
description = data.describe()
means = description.loc['mean']
delete_columns = means[means == 0].index
data_avg_equal_zero = data.drop(columns=delete_columns)
print(data_avg_equal_zero)
# Out:
# Delete features with average equal to Zero
#                   time                       carrera acepta  \
# Unnamed: 0
# 0           2020-11-08        Ingeniería de Sistemas     Si
# 1           2020-11-08                    Psicología     Si
# 2           2020-11-08        Ingeniería de Sistemas     Si
# 3           2020-11-08        Ingeniería de Sistemas     Si
# 4           2020-11-08        Ingeniería de Sistemas     Si
# ...                ...                           ...    ...
# 230         2020-12-10  Gestión Turística y Hotelera     Si
# 231         2020-12-11        Ingeniería de Sistemas     No
# 232         2020-12-11  Gestión Turística y Hotelera     No
# 233         2020-12-11         Ingeniería Agronómica     Si
# 234         2020-12-12        Comercio Internacional     Si
#
#                                  positivo  \
# Unnamed: 0
# 0                       Horario flexible.
# 1           Acceso desde cualquier lugar.
# 2                       Horario flexible.
# 3                       Horario flexible.
# 4           Acceso desde cualquier lugar.
# ...                                   ...
# 230                     Horario flexible.
# 231         Acceso desde cualquier lugar.
# 232                     Horario flexible.
# 233         Acceso desde cualquier lugar.
# 234                     Horario flexible.
#
#                                                      negativo  edad    sexo  \
# Unnamed: 0
# 0                      Contacto Personal Docente-Estudiantil.    20  Hombre
# 1                      Contacto Personal Docente-Estudiantil.    26  Hombre
# 2           Falta de recursos de calidad(plataformas, doce...    20   Mujer
# 3                                        Conexión a internet.    18   Mujer
# 4                      Contacto Personal Docente-Estudiantil.    39  Hombre
# ...                                                       ...   ...     ...
# 230                                      Conexión a internet.    19   Mujer
# 231         Falta de recursos de calidad(plataformas, doce...    23   Mujer
# 232         Falta de recursos de calidad(plataformas, doce...    25  Hombre
# 233                    Contacto Personal Docente-Estudiantil.    20   Mujer
# 234         Falta de recursos de calidad(plataformas, doce...    23  Hombre
#
#              trabajo
# Unnamed: 0
# 0           Eventual
# 1           Eventual
# 2                 Sí
# 3                 No
# 4                 Sí
# ...              ...
# 230               Sí
# 231               No
# 232               Sí
# 233               Sí
# 234               Sí
#
# [222 rows x 8 columns]

# %%
#Identify Type of data of each feature
print("Identify Type of data of each feature")
datatypes = data.dtypes
#Aquí pues solo pido los tipos de datos dentro de otra variable con dtypes y después los imprimo
print(datatypes)
# Out:
# Identify Type of data of each feature
# time        object
# carrera     object
# acepta      object
# positivo    object
# negativo    object
# edad         int64
# sexo        object
# trabajo     object
# dtype: object

# %%
#Función para validar que los números son valores númericos
def is_numeric(value):
    try:
        float(value)
        return True
    except (ValueError, TypeError):
        return False

#Validate that Numbers are numeric values
print("Validate that Numbers are numeric values")
is_numeric_dataset = data.applymap(is_numeric)
non_numeric_values_exist = not is_numeric_dataset.all().all()

if non_numeric_values_exist:
    print("There are non-numeric values in the dataset.")
else:
    print("All values in the dataset are numeric.")
# Out:
# Validate that Numbers are numeric values
# There are non-numeric values in the dataset.
# C:\Users\Personal\AppData\Local\Temp\ipykernel_12052\3262461974.py:11: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   is_numeric_dataset = data.applymap(is_numeric)

# %%
#Identify Categorical Features -: Generate the corresponding Dummy columns
print("Identify Categorical Features -: Generate the corresponding Dummy columns")
data_categories = data.select_dtypes(include=['object', 'category'])
print(data_categories)
# Out:
# Identify Categorical Features -: Generate the corresponding Dummy columns
#                   time                       carrera acepta  \
# Unnamed: 0
# 0           2020-11-08        Ingeniería de Sistemas     Si
# 1           2020-11-08                    Psicología     Si
# 2           2020-11-08        Ingeniería de Sistemas     Si
# 3           2020-11-08        Ingeniería de Sistemas     Si
# 4           2020-11-08        Ingeniería de Sistemas     Si
# ...                ...                           ...    ...
# 230         2020-12-10  Gestión Turística y Hotelera     Si
# 231         2020-12-11        Ingeniería de Sistemas     No
# 232         2020-12-11  Gestión Turística y Hotelera     No
# 233         2020-12-11         Ingeniería Agronómica     Si
# 234         2020-12-12        Comercio Internacional     Si
#
#                                  positivo  \
# Unnamed: 0
# 0                       Horario flexible.
# 1           Acceso desde cualquier lugar.
# 2                       Horario flexible.
# 3                       Horario flexible.
# 4           Acceso desde cualquier lugar.
# ...                                   ...
# 230                     Horario flexible.
# 231         Acceso desde cualquier lugar.
# 232                     Horario flexible.
# 233         Acceso desde cualquier lugar.
# 234                     Horario flexible.
#
#                                                      negativo    sexo  \
# Unnamed: 0
# 0                      Contacto Personal Docente-Estudiantil.  Hombre
# 1                      Contacto Personal Docente-Estudiantil.  Hombre
# 2           Falta de recursos de calidad(plataformas, doce...   Mujer
# 3                                        Conexión a internet.   Mujer
# 4                      Contacto Personal Docente-Estudiantil.  Hombre
# ...                                                       ...     ...
# 230                                      Conexión a internet.   Mujer
# 231         Falta de recursos de calidad(plataformas, doce...   Mujer
# 232         Falta de recursos de calidad(plataformas, doce...  Hombre
# 233                    Contacto Personal Docente-Estudiantil.   Mujer
# 234         Falta de recursos de calidad(plataformas, doce...  Hombre
#
#              trabajo
# Unnamed: 0
# 0           Eventual
# 1           Eventual
# 2                 Sí
# 3                 No
# 4                 Sí
# ...              ...
# 230               Sí
# 231               No
# 232               Sí
# 233               Sí
# 234               Sí
#
# [222 rows x 7 columns]
